# %%
from environments.group_guidance_environment import GroupGuidanceEnv
import numpy as np

env = GroupGuidanceEnv()

env.reset()
env.render()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.step([0])
# Out:
# (array([ 5., 15.]), -15.811388300841896, False, {})

# %%
env.render()

# %%
actions = [0, 45.0, 90.0, 135.0, 180.0, 275.0, 360.0]
for action in actions:
    env.step([action])
    env.render()
# Out:
# Obstacle collided at : [20.9733391  15.71467709]

# %%
from environments.group_guidance_environment import GroupGuidanceEnv
from agents.group_guidance_egent import GroupGuidanceAgent

env = GroupGuidanceEnv()
agent = GroupGuidanceAgent(env)

agent.run(episodes=3, steps=20)
# Out:
# Episode 1 / 3
# Obstacle collided at : [0.98326027 8.70813234]
# Step 1: Action=[312.71225], State=[1.71802974 8.02981544], Reward=-8.211550532134197
# Obstacle collided at : [7.85484354 0.99770133]
# Step 2: Action=[138.88931], State=[7.19732778 1.75114212], Reward=-7.407295452007259
# Obstacle collided at : [5.71106351 0.99695625]
# Step 3: Action=[243.09506], State=[6.60282207 1.44946777], Reward=-6.760045571055313
# Step 4: Action=[23.121622], State=[10.52966399 10.6462016 ], Reward=-14.973824904136283
# Obstacle collided at : [20.05371129 10.2255321 ]
# Step 5: Action=[92.52907], State=[19.05468532 10.26965827], Reward=-21.64594451223519
# Step 6: Action=[335.90524], State=[14.97221449 19.39837307], Reward=-24.50436868464754
# Step 7: Action=[26.087448], State=[19.36963865 28.37961227], Reward=-34.359646305934646
# Step 8: Action=[190.01787], State=[17.63008529 18.53207678], Reward=-25.57846315079421
# Step 9: Action=[231.31677], State=[ 9.82395285 12.28193314], Reward=-15.727553248937749
# Step 10: Action=[198.41025], State=[6.66576558 2.79373796], Reward=-7.22754471125627
# Step 11: Action=[52.494156], State=[14.59867829  8.88216109], Reward=-17.08842278806578
# Step 12: Action=[311.2025], State=[ 7.07481855 15.46938569], Reward=-17.010436536608008
# Step 13: Action=[25.781706], State=[11.42425442 24.47396249], Reward=-27.009043468248116
# Step 14: Action=[24.51008], State=[15.57278776 33.57284517], Reward=-37.008751009885174
# Step 15: Action=[61.58521], State=[24.36804497 38.33135844], Reward=-45.42130178183925
# Step 16: Action=[127.03818], State=[32.350389   32.30788887], Reward=-45.720316621798226
# Obstacle collided at : [35.23851929 40.05362822]
# Step 17: Action=[20.448824], State=[34.88914868 39.1166436 ], Reward=-52.41530789871085
# Step 18: Action=[158.60333], State=[38.53737524 29.80587357], Reward=-48.718778609985506
# Step 19: Action=[15.593998], State=[41.22556439 39.43778091], Reward=-57.05160578019395
# Obstacle collided at : [40.78017929 40.02036987]
# Step 20: Action=[322.60236], State=[41.3875226  39.22593038], Reward=-57.022808080871265
# Episode 2 / 3
# Obstacle collided at : [0.98249257 6.43668989]
# Step 1: Action=[289.67743], State=[1.9240959  6.09996569], Reward=-6.396227512928611
# Obstacle collided at : [0.96578346 4.49806621]
# Step 2: Action=[210.88934], State=[1.47916511 5.35622662], Reward=-5.5567160237880335
# Step 3: Action=[58.495525], State=[10.00515833 10.58187848], Reward=-14.562944255185558
# Step 4: Action=[158.5287], State=[13.66550878  1.27586787], Reward=-13.724939670404883
# Obstacle collided at : [20.03782285  2.71741449]
# Step 5: Action=[77.25309], State=[19.06246864  2.4967696 ], Reward=-19.22528463029443
# Obstacle collided at : [18.88888433  0.97329345]
# Step 6: Action=[186.50023], State=[19.00209149  1.96686486], Reward=-19.103613226586415
# Obstacle collided at : [20.01942948  1.64623866]
# Step 7: Action=[107.49287], State=[19.0656751   1.94682573], Reward=-19.16481404439642
# Obstacle collided at : [20.00537791  6.38169537]
# Step 8: Action=[11.963433], State=[19.79809052  5.40341527], Reward=-20.522214427482357
# Obstacle collided at : [20.03466659  5.28035889]
# Step 9: Action=[117.48145], State=[19.14750633  5.74182035], Reward=-19.98988493367114
# Obstacle collided at : [20.03959529  6.01620777]
# Step 10: Action=[72.90323], State=[19.08378572  5.72222125], Reward=-19.92321995847083
# Obstacle collided at : [14.41185008  0.96643937]
# Step 11: Action=[224.49045], State=[15.11264043  1.67980665], Reward=-15.205711138328933
# Obstacle collided at : [15.82731997  0.98035461]
# Step 12: Action=[134.38306], State=[15.11264043  1.67980665], Reward=-15.205711139476366
# Obstacle collided at : [11.64672767  0.992862  ]
# Step 13: Action=[258.78925], State=[12.62764639  1.1872803 ], Reward=-12.683338986497677
# Step 14: Action=[289.02948], State=[3.17413694 4.44782633], Reward=-5.464275284075105
# Obstacle collided at : [4.73205754 0.98186574]
# Step 15: Action=[155.79648], State=[4.32207842 1.89396066], Reward=-4.718839780257226
# Step 16: Action=[93.56161], State=[14.30276414  1.27274361], Reward=-14.359280560480848
# Obstacle collided at : [12.93236428  0.98637992]
# Step 17: Action=[258.1971], State=[13.91122134  1.19092542], Reward=-13.962105228049506
# Obstacle collided at : [14.00457812  0.94113426]
# Step 18: Action=[159.50731], State=[13.65449018  1.8778511 ], Reward=-13.783012259414631
# Obstacle collided at : [20.02953048  6.13656402]
# Step 19: Action=[56.25592], State=[19.19800346  5.58107971], Reward=-19.992793391864538
# Step 20: Action=[268.47787], State=[9.20153205 5.31545079], Reward=-10.626486216210155
# Episode 3 / 3
# Obstacle collided at : [7.61272478 0.97337999]
# Step 1: Action=[147.02196], State=[7.06840711 1.81225917], Reward=-7.297031067769068
# Step 2: Action=[338.96292], State=[ 3.47868639 11.14574215], Reward=-11.675993623312495
# Obstacle collided at : [0.98691831 8.83249944]
# Step 3: Action=[227.12779], State=[1.71979128 9.51286495], Reward=-9.667072023973262
# Obstacle collided at : [2.60563568 0.95860988]
# Step 4: Action=[174.08775], State=[2.50263052 1.9532907 ], Reward=-3.1746659765723817
# Obstacle collided at : [2.54341754 0.95412284]
# Step 5: Action=[177.66243], State=[2.50263052 1.9532907 ], Reward=-3.1746659786768596
# Obstacle collided at : [3.61291611 0.99497078]
# Step 6: Action=[130.79843], State=[2.85590321 1.64837072], Reward=-3.2974701220488334
# Obstacle collided at : [3.41006611 0.98202649]
# Step 7: Action=[140.25151], State=[2.7706474 1.7508852], Reward=-3.2775121666240223
# Obstacle collided at : [3.12366279 0.95937317]
# Step 8: Action=[155.96307], State=[2.71633735 1.87265625], Reward=-3.299292358000929
# Obstacle collided at : [0.9901413  1.16223963]
# Step 9: Action=[247.63037], State=[1.91488917 1.54281996], Reward=-2.4590839634530455
# Step 10: Action=[27.40018], State=[ 6.51691491 10.42095921], Reward=-12.29091416157162
# Step 11: Action=[112.28221], State=[15.77018971  6.62927053], Reward=-17.106902448486142
# Step 12: Action=[335.41635], State=[11.60997743 15.72281978], Reward=-19.544785442580064
# Step 13: Action=[301.08124], State=[ 3.0456155  20.88534913], Reward=-21.106245100059652
# Obstacle collided at : [ 0.95133777 21.91415675]
# Step 14: Action=[296.16245], State=[ 1.84888537 21.4732392 ], Reward=-21.552688436084708
# Step 15: Action=[85.08845], State=[11.81216593 22.3294173 ], Reward=-25.261237918069757
# Step 16: Action=[345.79694], State=[ 9.35857307 32.02373965], Reward=-33.36319515724486
# Step 17: Action=[198.5069], State=[ 6.18438553 22.54088505], Reward=-23.373876935906516
# Obstacle collided at : [ 0.94317799 23.84078667]
# Step 18: Action=[283.9292], State=[ 1.91377196 23.60006415], Reward=-23.67753261784735
# Obstacle collided at : [ 0.98517392 23.97115122]
# Step 19: Action=[291.78268], State=[ 1.91377199 23.60006414], Reward=-23.677532610225565
# Obstacle collided at : [ 0.99368502 21.16830756]
# Step 20: Action=[200.7248], State=[ 1.34756462 22.10359854], Reward=-22.144638155030055

# %%
print(np.radians(150))

# %%
np.cos(np.radians(0))

# %%
np.sin(np.radians(0))
