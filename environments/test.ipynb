# %%
import gym
import numpy as np

# %%
print(gym.__version__)
print(np.__version__)
# Out:
# 0.26.2
# 1.26.3

# %%
import group_guidance_environment as gge
import plot as pe

# %%
env = gge.GroupGuidanceEnv()
renderer = pe.DrawEnv(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
renderer.render()

# %%
action = np.array([45.0])
env.step(action)
renderer.render()

# %%
action = np.array([45.0])
env.step(action)
renderer.render()

# %%
env = gge.GroupGuidanceEnv()

env.reset()
env.render()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
actions = [45.0, 45.0, 90.0, 135.0, 200.0]
for action in actions:
    env.step(np.array([action]))
    env.render()
